# %% [markdown]
# ### Level 1
#
# - Be Perfect with all Python Fundamental Basics
#
# ### Basics Concepts
#         - Installation
#         - Variables , Data types , Operators , Keywords
#         - Build-In DataTypes Like List , Tuple , Set , Strinh , Dictionary , Ordered Dict and methods of them
#         - Conditional And Looping Statements
#         - List , and Dictionary Comprehension
# ### Intermediate Concepts
#             - Functions , Lambda , Nested Functions
#             - map , reduce , filter methods
#             -  Classes & Objects
#             - All OOP's concepts like Inheritance , Polymoriphism , Encapsulation
#             - Class Methods and Decorators
# ### Advance Concepts
#             - Packages
#             - Modules installations
#             - Knowing the built modules like sys, os, pathlib, random , hashlib
#             - libraries like Collections, itertools
#             - API's
#             - Databases
#
#
#
#
# ## Level 2
#         - Learning the packages and modules required for different domains
#   ### Web-Development
#       - Flask
#       - Django
#       - Bottle
#       - CheeryPy
#       - Pyramid
# ### Machine Learning
#         - TensorFlow
#         - Scikit-Learn
#         - Keras
#         - PyTorch
#         - Theano
# ###  Game Developement
#         - PyGame
#         - PyGlet
#         - PyOpenGI
#         - Arcade
# ### Web Scarping
#         - requests
#         - Beautiful Soup
#         - Selenium
#         - Lxml
#         - Scrapy
# ###  Image Processing
#         - OpenCv
#         - Mahotas
#         - SimpleITK
#         - Pillow
# ### Automation Testing
#         - Splinter
#         - Robot
#         - Behave
#         - PyTest
#
# ## Level 3
#
#     - To Enhance your Python Skills
#      - Build Projects
#      -  Contribute to Open Source (GitHub)
#      - Read Other Dev's code
#      - Learn DataStructures and Algo
#      - Learn By Doing Real
#     - Join Python Community in Discord Servers , Reddit Pages To KeepUpdated with Python New Changes.
#      -  Write Ariticles or Blogs on Medium , Dev etc
#      - Share Knowledge through blogs , videos, webinars etc

# %% [markdown]
# ### Scope after Python
#
# <img src = "https://www.edureka.co/blog/wp-content/uploads/2016/02/PythonApplications-Python-Career-Opurtunity-Edureka-1.png">

# %% [markdown]
# ### Best WebSites for Interview Preparation
#
# 1. **InterViewBit**     <br>
#
# https://www.interviewbit.com/
#
# <br>
#
# 2. **LeetCode**
#
#  https://leetcode.com/
#
#
# 3.**GeeksForGeeks**
#
#
# https://www.geeksforgeeks.org/
#
# 4.**Glass Door**
#
# https://www.glassdoor.com/index.htm
#
# 5 **HackerRank**
#
#
# https://www.hackerrank.com/
#
#
# 6.**HackerEarth**
#
#
# https://www.hackerearth.com/

# %% [markdown]
# ### Best Websites for Python Lookup
#
# 1. **Python Documentaion**
#
#  https://docs.python.org/
#
#
#  2. **W3 Schools**
#
#  https://www.w3schools.com/
#
#
#  2. **Real Python**
#
#  https://realpython.com/
#
#
# 3. **GeeksForGeeks**
#
# https://www.geeksforgeeks.org/
#
# 4. **FreeCodeCamp**
#
# https://www.freecodecamp.org/
#
#
# 5 . **LearnPython**
#
#  https://www.learnpython.org

# %% [markdown]
# ### Best Resources For DataScience and ML
#
# <img src =" data:image/jpeg;charset=utf-8;base64,...">
